# %% [markdown]
# <a href="https://colab.research.google.com/github/balasaniajay1992/Python/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Syntax: []
# Features of List
# Background data structure  - Array
# It supports Indexing and slicing
# It accepts all data types
# We can create Hemo and Hetro lists
# It preservers sequence order
# It allows duplicates records
# List is mutable in natures

# Question: Explain features of a list?

# %%
help(list.append)
# Out:
# Help on method_descriptor:
#
# append(self, object, /) unbound builtins.list method
#     Append object to the end of the list.

# %%
# How to create an empty list ?
a=[]
a
# Out:
# []

# %%
#2
b=list()
b
# Out:
# []

# %%
# Assignment: How to create an empty string
a=''
a
# Out:
# ''

# %%
b=str()
b
# Out:
# ''

# %%
# To add elements in empty list/a normal then use append(object) method
a=[]
a.append(100)
a
# Out:
# [100]

# %%
# operations in list are inplace/parmnt

# %%
# Assignment: try to add str, list,tuple,set,dict
a
# Out:
# [100]

# %%
data =(1,2,3)
data
# Out:
# (1, 2, 3)

# %%
# Add above data in a
a.append(data) # This will add a complete tuple a
a
# Out:
# [100, (1, 2, 3), (1, 2, 3)]

# %%
# add c++
a.append('c++')
a
# Out:
# [100, (1, 2, 3), (1, 2, 3), 'c++']

# %%
# append adds a complete object as it is

# %%
# Use extend() to add individual elements from an iterable collection of elements
b=[]
b
# Out:
# []

# %%
b.extend(data)
b
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 2, 3, 'c', '+', '+', 'c', '+', '+']

# %%
b.extend('JAVA')
b
# Out:
# [1, 2, 3, 'c', '+', '+', 'c', '+', '+', 'J', 'A', 'V', 'A']

# %%
# Q Append vs Extend
# Append() add total object at the end
# Extend() add individual elements from the object
# both add at the end of the object

# %%
# to remove the elemnts from the list we have 2 methods
# pop() removes last element as default
b.pop()
b
# Out:
# [1, 2, 3, 'c', '+', '+', 'c', '+', '+', 'J', 'A', 'V']

# %%
b
# Out:
# [1, 2, 3, 'c', '+', '+', 'c', '+', '+', 'J', 'A', 'V']

# %%
a
# Out:
# [100, (1, 2, 3), (1, 2, 3), 'c++']

# %%
a.pop()
a
# Out:
# [100, (1, 2, 3), (1, 2, 3)]

# %%
k=[1,2,3,4,5,6,7]
k
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
# pop(index)--> we can remove element with its index
k.pop(2)
# Out:
# 3

# %%
help(k.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
# remove(value)--> it will remove the value directly
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
k.remove(6)

# %%
# Difference between pop(index) and remove(value)

# %%
help(k.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
t=[1,2,3,1,1,4,5,1,1]
t.remove(1)
t
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
k
# Out:
# [1, 2, 4, 5, 7]

# %%
# remove all elements
k.clear()

# %%
k
# Out:
# []

# %%
help(k.clear)
# Out:
# Help on built-in function clear:
#
# clear() method of builtins.list instance
#     Remove all items from list.

# %%
t
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
# shallow copy - list is with same elements but id are diffrent
x=t.copy()
x
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
id(t),id(x)
# Out:
# (132378617928128, 132378617712000)

# %%
# add -1 in x
x.append(-1)
x
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1]

# %%
t
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
id(x[1]),id(t[1])
# Out:
# (11645416, 11645416)

# %%
id(t),id(x)
# Out:
# (132378617928128, 132378617712000)

# %%
# Deep copy
y = x
y
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1]

# %%
x
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1]

# %%
# in above case we have 1 object with different names x,y hence
# if we change in either x/y changes will get reflected in both of the list
x.append('python')
x
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1, 'python']

# %%
y
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1, 'python']

# %%
id(x),id(y)
# Out:
# (132378617712000, 132378617712000)

# %%
id(x[1]),id(y[1])
# Out:
# (11645416, 11645416)

# %%
r1=[]
r1
# Out:
# []

# %%
r2=r1
r2
# Out:
# []

# %%
r1.append(500)
r1
# Out:
# [500]

# %%
r2
# Out:
# [500]

# %%
r2.extend([20,30])
r2
# Out:
# [500, 20, 30]

# %%
r1
# Out:
# [500, 20, 30]

# %%
# Assignment can we add a tuple to a list using extend
q=[1,2,3,4]
q.extend((5,6,7,8,'uygyug'))
q
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 'uygyug']
