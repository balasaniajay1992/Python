# %% [markdown]
# <a href="https://colab.research.google.com/github/balasaniajay1992/Python/blob/main/Tuplemethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tuple
# suntax:()
t=()
type(t)
# Out:
# tuple

# %%
# Tuple has same features as that of list
# It accepts homo./hetro. data
a=(1,2,3) # data is of same type---> homo
b=(1.23,33,6+5j,'ajay') # Data is of different type---> hetro
a
# Out:
# (1, 2, 3)

# %%
b
# Out:
# (1.23, 33, (6+5j), 'ajay')

# %%
# Tuple supports indexing and slicing bez background data structure is an Array

# %%
# access middle 2 elements
b[1:3]
# Out:
# (33, (6+5j))

# %%
# Tuple preservers sequence order
# Duplicates are allowed in tuple
# Tuple is Immutable in nature

# %%
# In data type we have 2 approaches
# 1. Mutable data type -> in which we can directly perform the changes(add,upadte,remove,instert)
# Example: List,set,dict
# 2. Immuatble data types--> In which we can't perform the changes in the orignal object,changes remain temp
# Ex: Tuple, string, range

# %%
p=[10,20,30]
p
# Out:
# [10, 20, 30]

# %%
# list is mutable
# lets try to change element 30
p[-1]='Ajay'
p
# Out:
# [10, 20, 'Ajay']

# %%
#remove 10
p.remove(10)
p
# Out:
# [20, 'Ajay']

# %%
# Use insert() to add an element using index
p.insert(0,'Vihhan')
p
# Out:
# ['Vihhan', 20, 'Ajay']

# %%
#Lets try to understand Immutable concept
# in which user can't able to change inj the orignal object
t=(10,20,30)
t
# Out:
# (10, 20, 30)

# %%
# lets replace last element
t[-1]='Anu'
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3617/434774852.py in <cell line: 0>()
#       1 # lets replace last element
# ----> 2 t[-1]='Anu'
#       3 t
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Assignment: Tuple conatins 2 methods
#count() and index()
v=(1,2,3,4,1,2,3,4,5,6,8)
v.count(1)
# Out:
# 2

# %%
v=(1,2,3,4,1,2,3,4,5,6,8)
v.index(2)
# Out:
# 1

# %%
help(tuple.count)
# Out:
# Help on method_descriptor:
#
# count(self, value, /) unbound builtins.tuple method
#     Return number of occurrences of value.

# %%
help(tuple.index)
# Out:
# Help on method_descriptor:
#
# index(self, value, start=0, stop=9223372036854775807, /) unbound builtins.tuple method
#     Return first index of value.
#
#     Raises ValueError if the value is not present.

# %%
# Tuple packing and Un packing
a=100
b='ajay'
c=300
a,b,c
# packing: combine segregated/seperate elements as a one entity
# Out:
# (100, 'ajay', 300)

# %%
# packing:
nums=a,b,c

# %%
nums
# Out:
# (100, 'ajay', 300)

# %%
# Unpacking: It is a process of separting the individual object and store it in separate variable called as unpacking
num1,name,num2 = nums

# %%
name
# Out:
# 'ajay'

# %%
# Assignment: Check packing and unpacking in list
