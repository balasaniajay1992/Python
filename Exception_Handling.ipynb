# %% [markdown]
# <a href="https://colab.research.google.com/github/balasaniajay1992/Python/blob/main/Exception_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exception Handling**
#
# Exception = Error

# %%
# Exception= Error
try:
  #print(30+20) # line without error
  print(30+'P')  # line with error
except:
  print('Error occur')

for i in range(5):
  print(i)
# Out:
# Error occur
# 0
# 1
# 2
# 3
# 4

# %%
try:
  print(30+20) # line without error
  #print(30+'P')  # line with error
except:
  print('Error occur')

for i in range(5):
  print(i)
# Out:
# 50
# 0
# 1
# 2
# 3
# 4

# %%
# to handle the exception we must need 2 blocks
# try: to best the code
# except: to handle the exception
print(-9/2)
# Out:
# -4.5

# %%
try:
  #print(30+'P')  # line with error
  #print(30/0)
  #print(int('ten))
  print(30+a)
except Exception as msg:
  print('Error occur:',msg)
# Out:
# Error occur: name 'a' is not defined

# %%
print(int('ten'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1410/4176583698.py in <cell line: 0>()
# ----> 1 print(int('ten'))
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
try:
  print(30+'P')  # line with error
  #print(30/0)
  #print(int('ten'))
  #print(30+a)
except TypeError as msg:
  print('TypeError:',msg)
# Out:
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# try: test code
# except: to handle exception
# else: if no exception then come here

# %%
try:
  #print(10/4) # without exception
  print(10/0) # with exception
except Exception as msg:
  print(msg)
else:
  print('No exception do below tasks....')
finally:
  print('Zukega nai sala....')
# Out:
# division by zero
# Zukega nai sala....

# %%
try:
  print(10/4) # without exception
  #print(10/0) # with exception
except Exception as msg:
  print(msg)
else:
  print('No exception do below tasks....')
finally:
  print('Zukega nai sala....')
# Out:
# 2.5
# No exception do below tasks....
# Zukega nai sala....

# %%
try:
  #print(10/4) # without exception
  print(10/0) # with exception ZeroDivisonError

  print(int('ten')) # eith exception ValueError
except Exception as msg:
  print(msg)
else:
  print('No exception do below tasks....')
finally:
  print('Zukega nai sala....')
# Out:
# division by zero
# Zukega nai sala....

# %%
# Example of ATM operation
try:
  balance = 5000
  amount = int(input('Enter amout in Rs.'))

  if  amount > balance:
    raise ValueError('Insufficient balance..')

except ValueError as e:
  print('Error:',e)

else:
  balance = balance - amount
  print('Withdrawal succesfull....')
  print('Remaining Amount is Rs. ',balance)

finally:
  print('Thank you for banking with us Visit Again.. :-)')
# Out:
# Enter amout in Rs.7000
# Error: Insufficient balance..
# Thank you for banking with us Visit Again.. :-)

# %%
# Example of ATM operation
try:
  balance = 5000
  amount = int(input('Enter amout in Rs.'))

  if  amount > balance:
    raise ValueError('Insufficient balance..')

except ValueError as e:
  print('Error:',e)

else:
  balance = balance - amount
  print('Withdrawal succesfull....')
  print('Remaining Amount is Rs. ',balance)

finally:
  print('Thank you for banking with us Visit Again.. :-)')
# Out:
# Enter amout in Rs.3000
# Withdrawal succesfull....
# Remaining Amount is Rs.  2000
# Thank you for banking with us Visit Again.. :-)

# %%
# Example of ATM operation
try:
  balance = 5000
  amount = int(input('Enter amout in Rs.'))

  if  amount > balance:
    raise ValueError('Insufficient balance..')

except ValueError as e:
  print('Error:',e)

else:
  balance = balance - amount
  print('Withdrawal succesfull....')
  print('Remaining Amount is Rs. ',balance)

finally:
  print('Thank you for banking with us Visit Again.. :-)')
# Out:
# Enter amout in Rs.dggs
# Error: invalid literal for int() with base 10: 'dggs'
# Thank you for banking with us Visit Again.. :-)

# %%
# Nested try except
try:
  pin = int(input('Enter your 4 digit pin:'))
  try:
    balance = 5000
    amount = int(input('Enter amout in Rs.'))

    if  amount > balance:
      raise ValueError('Insufficient balance..')

  except ValueError as e:
    print('Error:',e)

  else:
    balance = balance - amount
    print('Withdrawal succesfull....')
    print('Remaining Amount is Rs. ',balance)

except ValueError:
  print('Invalid PIN please enter 4 digit number ONLY')

finally:
    print('Thank you for banking with us Visit Again.. :-)')
# Out:
# Enter your 4 digit pin:yggv
# Invalid PIN please enter 4 digit number ONLY
# Thank you for banking with us Visit Again.. :-)

# %%
try:
  pin = int(input('Enter your 4 digit pin:'))
  try:
    balance = 5000
    amount = int(input('Enter amout in Rs.'))

    if  amount > balance:
      raise ValueError('Insufficient balance..')

  except ValueError as e:
    print('Error:',e)

  else:
    balance = balance - amount
    print('Withdrawal succesfull....')
    print('Remaining Amount is Rs. ',balance)

except ValueError:
  print('Invalid PIN please enter 4 digit number ONLY')

finally:
  print('Thank you for banking with us Visit Again.. :-)')
# Out:
# Enter your 4 digit pin:1234
# Enter amout in Rs.1500
# Withdrawal succesfull....
# Remaining Amount is Rs.  3500
# Thank you for banking with us Visit Again.. :-)

# %%
try:
  pin = int(input('Enter your 4 digit pin:'))
  try:
    balance = 5000
    amount = int(input('Enter amout in Rs.'))

    if  amount > balance:
      raise ValueError('Insufficient balance..')

  except ValueError as e:
    print('Error:',e)

  else:
    balance = balance - amount
    print('Withdrawal succesfull....')
    print('Remaining Amount is Rs. ',balance)

except ValueError:
  print('Invalid PIN please enter 4 digit number ONLY')

finally:
  print('Thank you for banking with us Visit Again.. :-)')
# Out:
# Enter your 4 digit pin:1234
# Enter amout in Rs.8000
# Error: Insufficient balance..
# Thank you for banking with us Visit Again.. :-)
