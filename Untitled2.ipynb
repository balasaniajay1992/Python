# %% [markdown]
# <a href="https://colab.research.google.com/github/balasaniajay1992/Python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Types in Python
# Set
# syntax: {atleast one element} is a set
type({})
# Out:
# dict

# %%
type({12})
# Out:
# set

# %%
a={1,2,3} # Homogenious
a
# Out:
# {1, 2, 3}

# %%
b={1,'A',2.22,'Python'} # Hetrogenious
b
# Out:
# {1, 2.22, 'A', 'Python'}

# %%
# dist:
# syntax: {key:value}
d1={1:100,2:200,3:300}
type(d1)
# Out:
# dict

# %%
# String is immutable data type
# we can not change the string ones it is created and we can't modify or update the string
# String background data structure is an Array
# String is an ordered collection of data

# %%
# Array is a collection of sequential elements
# s= 'python'
# p index is----> 0

# %%
# Strings in Index Operation
s='PYTHON'
s[0]
# Out:
# 'P'

# %%
id(s[1]),id(s[2]),id(s[3])
# Out:
# (11707568, 11707328, 11706752)

# %%
# Indexing is of 2 types
# +ve Indexing ----> starts with 0 and ends at n-1(left to right)
# -ve Indexing ----> starts with -1 and end at -n (Right to left)
s[-1]
# Out:
# 'N'

# %%
# len function to find the total character of string with the help of floating we can find the middle of index
len(s),len(s)//2
# Out:
# (6, 3)

# %%
# Slicing
# Using this we can access more than one element
s
# Out:
# 'PYTHON'

# %%
s[:] #[start:stop:step]
s[2:]
# Out:
# 'THON'

# %%
s[2:-1]
# Out:
# 'THO'

# %%
# Assignment PY, YTH, HO
s[:2],s[1:-2],s[-3:-1]
# Out:
# ('PY', 'YTH', 'HO')

# %%
addrs= 'jnkjnbjkjn bjhbhjb Pin-500010'
addrs[-6:]
# Out:
# '500010'

# %%
s
# Out:
# 'PYTHON'

# %%
s[::2]
# Out:
# 'PTO'

# %%
s[::-1]
# Out:
# 'NOHTYP'

# %%
#[start:stop:step]
n='ajay kumar'
n[::-1] # reverse the string
# Out:
# 'ramuk yaja'

# %%
# Assignment
p= 'I love my India'
# Access: my,India,I love,ove,love my,my India
p[7:9],p[-5:],p[:6],p[3:6],p[2:-6],p[-8:]
# Out:
# ('my', 'India', 'I love', 'ove', 'love my', 'my India')

# %%
# String Methods
s
# Out:
# 'PYTHON'

# %%
#Conver string in lower case
s.lower(),
# Out:
# 'python'

# %%
# Capatalize() menthod
s.capitalize()
# Out:
# 'Python'

# %%
'ajay kumar balasani'.title()
# Out:
# 'Ajay Kumar Balasani'

# %%
# to remove space present in prefix and suffix use strip() method
'   python   '.strip() # default strip remove space
# Out:
# 'python'

# %%
'*************JAVA*******************'.strip('*')
# Out:
# 'JAVA'

# %%
'*********123 JAVA     ******'.strip('*123')
# Out:
# ' JAVA     '

# %%
# remove spaces present in between J A V A
' J A V 999 A '.replace(' ','').replace('999','')
# Out:
# 'JAVA'

# %%
s.casefold()
# Out:
# 'python'

# %%
' J A V 999 A '.casefold()
# Out:
# ' j a v 999 a '

# %%
# when we want to conver lower to upper and visa versa we use swap() method
h='gooG MoRinG'
h.swapcase()
# Out:
# 'GOOg mOrINg'

# %%
# startwith() method
code='ajay-jhbhjbhbhjnkjnjhb'
code .startswith('ajay') # it will return boolan output
# Out:
# True

# %%
code='ajay-jhbhjbhbhjnkjnjhb'
code .endswith('jhb') # it will return boolan output
# Out:
# True

# %%
from os.path import join
# join() is used to prepare a string using a collection
aadhar=['123','456','789']
''.join(aadhar)
# Out:
# '123456789'
