# %% [markdown]
# <a href="https://colab.research.google.com/github/balasaniajay1992/Python/blob/main/TypeCasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Typecasting/Type conversion
# we as a user wants to change a data type from one form to another
# ex: list--> tuple | tuple-->set

# %%
a=[1,2,3,4,1,1,2,2,3,3,3]
a
# Out:
# [1, 2, 3, 4, 1, 1, 2, 2, 3, 3, 3]

# %%
# Write a program to remove the duplicate
set(a) # temparory concept
# Out:
# {1, 2, 3, 4}

# %%
a
# Out:
# [1, 2, 3, 4, 1, 1, 2, 2, 3, 3, 3]

# %%
tuple(a)
# Out:
# (1, 2, 3, 4, 1, 1, 2, 2, 3, 3, 3)

# %%
# take an input from the user
per_day=float(input('Enter your per day income:Rs'))
days=float(input('Working days:'))
print('Final salary is Rs:',per_day*days)
# Out:
# Enter your per day income:Rs2000
# Working days:22.2
# Final salary is Rs: 44400.0

# %%
# Assignment: Create a simple bill of Grocery. Take 3-4 inputs and print the final bill

# %%
set('TEN')
# Out:
# {'E', 'N', 'T'}

# %%
# Ps: Take an input list/set/tuple/dict from the user

# %%
data=input('1,2,3,4')
data=input('Enter your data:')
print(data)
# Out:
# 1,2,3,4234
# Enter your data:345
# 345

# %%
# eval() function will help you to take the data in its original format
data=eval(input('Enter your data:'))
print(data)
print(type(data))
# Out:
# Enter your data:{1,22,12,34,4.45}
# {1, 34, 4.45, 22, 12}
# <class 'set'>

# %%
# Rule comma separted values in python are default Tuple

# %%
[1,2,3]*[3,2,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_350/629795197.py in <cell line: 0>()
# ----> 1 [1,2,3]*[3,2,1]
#
# TypeError: can't multiply sequence by non-int of type 'list'
