# %% [markdown]
# <a href="https://colab.research.google.com/github/balasaniajay1992/Python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Basics

# %% [markdown]
# Different types of Data Types

# %%
# 14 Data types
# Numeric: int, float, complex
# Boolan: True, False
# String: " "
# List
# Tuple
# Set
# Dict
# Frozenset
# None
# Bytes
# Bytearray
# Range

# %%
# Python is Dynamically types language
# Static typing-int a=20 | string s = 'python'
# Dynamic Typing a = 20 | s='python'
a=20
type(a)
# Out:
# int

# %%
s='python'
type(s)
# Out:
# str

# %%
a.upper()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_589/2984306047.py in <cell line: 0>()
# ----> 1 a.upper()
#
# NameError: name 'a' is not defined

# %%
s='python'
s.upper()
# Out:
# 'PYTHON'

# %%
x='python'
type(x)
# Out:
# str

# %%
x=10
type(x)
# Out:
# int

# %%
id(x)
# Out:
# 11645640

# %%
id(10)
# Out:
# 11645640

# %%
id('python')
# Out:
# 137847358176208

# %%
p='python'
id(p)
# Out:
# 137847358176208

# %%
e=[1,2,3]
id(e)
# Out:
# 137846352708224

# %%
t=[1,2,3]
id(t)
# Out:
# 137846351286528

# %%
id(e[1])
# Out:
# 11645384

# %%
id(t[1])
# Out:
# 11645384

# %%
# string in python
# Syntax:'' or ""

# %%
type('.net')
# Out:
# str

# %%
type("c++")
# Out:
# str

# %%
# List in python
# synatx:[]
q = [1,2,3]
r = ['A','B','C'] #Homogenious
p = ['X',10,22.22,'Y'] #Hetrogenious
type(q)
type(p)
type(r)
# Out:
# list

# %%
r = ['A','B','C']
type(r[1])
# Out:
# str

# %%
#Tuple in python
#synatx:()
t1=(1,2,3)
t2=('A','B','C') #Homo
t3=('X',10,22.22,'Y') #Hetro
type(t1),type(t2),type(t3)
# Out:
# (tuple, tuple, tuple)

# %%
#list[] vs tuple()
# list is mutable - means we can change the list
p.append(100)
p
# Out:
# ['X', 10, 22.22, 'Y', 100]

# %%
p = ['X',10.22,22,'Y']
p.insert(4,300.22)
p
# Out:
# ['X', 10.22, 22, 'Y', 300.22]

# %%
p = ['X',10.22,22,'Y']
p.index(22)
# Out:
# 2

# %%
p.count(22)
# Out:
# 1

# %%
p.

# %%
# Assignment : Difference between List and Tuple

# %%
# Assignment - Shallow copy and Deep copy

# %%
# Programiz python for learning
